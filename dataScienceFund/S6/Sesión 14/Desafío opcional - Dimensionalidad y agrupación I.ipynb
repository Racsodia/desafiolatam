# %% [markdown]
# <h1 style="text-align: center;">Desafío - Dimensionalidad y Agrupación I</h1>
#
# - Para realizar este desafío debes haber estudiado previamente todo el material disponible correspondiente a la unidad.
# - Una vez terminado el desafío, comprime la carpeta que contiene el desarrollo de los requerimientos solicitados y sube el .zip en el LMS.
# - Desarrollo del desafío: individual
# - Para la realización del desafío necesitarás apoyarte del archivo `Apoyo Desafío - Dimensionalidad y agrupación (I)`, disponible en la plataforma.

# %% [markdown]
# ## Contexto
# - Para esta actividad utilizaremos un subconjunto de 25 ítems de la International Personality Item Pool, aplicados a 2800 individuos.
# - El objetivo de esta información es desarrollar perfiles de personalidad en base a una serie de oraciones asociadas a las características de:
#     - Amabilidad
#     - Escrupulosidad
#     - Extroversión
#     - Neuroticismo
#     - Apertura
#
# - Los individuos deben responder qué tan adecuada es la oración respecto a su personalidad en base a 6 categorías:
#     - `1`: No me representa para nada.
#     - `2`: No me representa.
#     - `3`: Algunas cosas no me representan.
#     - `4`: Algunas cosas me representan.
#     - `5`: Me representa.
#     - `6`: Me representa completamente.
#
# - Las 25 preguntas son:
#     - `A1`: Soy indiferente a los sentimientos de otros.
#     - `A2`: Me preocupo del bienestar de otros.
#     - `A3`: Sé cómo confortar a otros.
#     - `A4`: Me agradan los niños.
#     - `A5`: Hago sentir tranquila a la gente.
#     - `C1`: Soy exacto en mi trabajo.
#     - `C2`: Sigo con mis tareas hasta que todo esté perfecto.
#     - `C3`: Hago cosas siguiendo un plan.
#     - `C4`: Hago cosas con el mínimo esfuerzo.
#     - `C5`: Pierdo mi tiempo.
#     - `E1`: No hablo mucho con las personas.
#     - `E2`: Me es difícil acercarme a otros.
#     - `E3`: Sé cómo cautivar a la gente.
#     - `E4`: Hago amigos de forma fácil.
#     - `E5`: Puedo tomar el cargo de las cosas.N1 Me enojo con facilidad.
#     - `N2`: Me irrito con facilidad.
#     - `N3`: Tengo cambios de humor frecuentes.
#     - `N4`: Usualmente me siento melancólico.
#     - `N5`: Entró en pánico con facilidad.
#     - `O1`: Estoy lleno de ideas.
#     - `O2`: Evito leer material difícil.
#     - `O3`: Tiendo a llevar la conversación a niveles más altos.
#     - `O4`: Dedico tiempo a la reflexión de cosas.
#     - `O5`: No profundizaré sobre una materia específica.
#
# - Se registraron una serie de covariables sobre características demográficas de los encuestados:
#     - `gender`: Masculino = 1, Femenino = 2.
#     - `education`: 1 = Educación Media Incompleta, 2 = Educación Media Completa, 3 = Educación Universitaria Incompleta, 4 = Educación Universitaria Completa, 5 = Estudios de Postgrado.
#     - `age`: Edad en Años.
#
# - Implementaremos un modelo de extracción factorial para identificar los principales perfiles psicológicos.

# %% [markdown]
# ## Desafío 1: Lectura de archivos
# - Importe las librerías necesarias para el análisis factorial siguiendo las convenciones.
# - Importe la base de datos `bfi.csv` y asígnela a un objeto `df`.
# - Solicite las primeras 5 observaciones con `head`.

# %%
# En caso de que no se tenga los módulos instalados, ejecutar esta celda como celda de código
# !pip install factor_analyzer
# !pip install missingno
# Out:
# Requirement already satisfied: factor_analyzer in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: pandas in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from factor_analyzer) (1.4.2)
# Requirement already satisfied: numpy in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from factor_analyzer) (1.21.5)
# Requirement already satisfied: scikit-learn in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from factor_analyzer) (1.0.2)
# Requirement already satisfied: scipy in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from factor_analyzer) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from pandas->factor_analyzer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from pandas->factor_analyzer) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->factor_analyzer) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->factor_analyzer) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->factor_analyzer) (2.2.0)
# Requirement already satisfied: missingno in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: numpy in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from missingno) (1.21.5)
# Requirement already satisfied: seaborn in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from missingno) (0.11.2)
# Requirement already satisfied: scipy in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from missingno) (1.7.3)
# Requirement already satisfied: matplotlib in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from missingno) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from seaborn->missingno) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/oscaraguilera/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)

# %%
# Utiliza esta celda para importar los módulos requeridos

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import factor_analyzer as fact
import missingno as msgno 

df = pd.read_csv("bfi.csv")
df.head()
# Out:
#    Unnamed: 0   A1   A2   A3   A4   A5  ...   O3   O4   O5  gender  education  age
# 0       61617  2.0  4.0  3.0  4.0  4.0  ...  3.0  4.0  3.0       1        NaN   16
# 1       61618  2.0  4.0  5.0  2.0  5.0  ...  4.0  3.0  3.0       2        NaN   18
# 2       61620  5.0  4.0  5.0  4.0  4.0  ...  5.0  5.0  2.0       2        NaN   17
# 3       61621  4.0  4.0  6.0  5.0  5.0  ...  4.0  3.0  5.0       2        NaN   17
# 4       61622  2.0  3.0  3.0  4.0  5.0  ...  4.0  3.0  3.0       1        NaN   17
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Desafío 2: Preprocesamiento
# - Elimine las columnas redundantes de la base, tal como `Unnamed: 0`.

# %%
# Utiliza esta celda para eliminar Unnamed: 0
df = df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# - Analice el patrón de datos perdidos con `missingno`.

# %%
# Utiliza esta celda para explorar los datos perdidos
msgno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Comente cuáles son las principales variables con mayores tasas de valores perdidos.
#
# **Respuesta:** La columna education es la que tiene más datos perdidos. Las demás están más o menos igual respecto a este aspecto.

# %% [markdown]
# - Genere un nuevo objeto donde almacenará la base sin valores perdidos.

# %%
# Utiliza esta celda para almacenar el set sin datos perdidos.
df = df.dropna()
msgno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Desafío 3: Descripción
# - Separe en un nuevo objeto `DataFrame` la batería de preguntas a extraer.

# %%
# Utiliza esta celda para generar el subset a partir del set sin datos perdidos. Tip: Puedes usar slice de la forma A1:O5
df_questions = df.loc[:, 'A1' :'O5']
df_questions.head()
# Out:
#      A1   A2   A3   A4   A5   C1   C2  ...   N4   N5   O1  O2   O3   O4   O5
# 5   6.0  6.0  5.0  6.0  5.0  6.0  6.0  ...  2.0  3.0  4.0   3  5.0  6.0  1.0
# 7   4.0  3.0  1.0  5.0  1.0  3.0  2.0  ...  6.0  4.0  3.0   2  4.0  5.0  3.0
# 10  4.0  4.0  5.0  6.0  5.0  4.0  3.0  ...  2.0  3.0  5.0   3  5.0  6.0  3.0
# 14  4.0  5.0  2.0  2.0  1.0  5.0  5.0  ...  2.0  3.0  5.0   2  5.0  5.0  5.0
# 22  1.0  5.0  6.0  5.0  6.0  4.0  3.0  ...  2.0  2.0  6.0   1  5.0  5.0  2.0
#
# [5 rows x 25 columns]

# %% [markdown]
# - Reporte las medias para cada una de las preguntas de la batería. Esto lo puede lograr con un dotplot.

# %%
# Utiliza esta celda para generar el plot solicitado. Tip: Puedes aplicar mean() al df completo y ordenar sus valores
plt.plot(df_questions.mean().sort_values(), 'o')
plt.grid()

# %% [markdown]
# - Genere una matriz de correlaciones con este nuevo objeto. Visualízalo con heatmap.

# %%
# Utiliza esta celda para generar el heatmap solicitado
sns.heatmap(df_questions.corr().abs(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Comente sobre los principales patrones de correlación entre las preguntas de la batería.
#
# **Respuesta**

# %% [markdown]
# ## Desafío 4: Extracción de factores
# - Antes de iniciar la extracción de factores, inspeccione la idoneidad de la batería de preguntas para realizar un análisis factorial mediante la prueba de esfericidad de Barlett y Kaiser-Meyer-Olkin.

# %%
# Utiliza esta celda para realizar la prueba de esferacidad de Barlett
estadistico, pvalue = fact.calculate_bartlett_sphericity(df_questions)
assert pvalue < 0.05

# %%
# Utiliza esta celda para realizar la prueba KMO
kmos_individuales, kmo_general = fact.calculate_kmo(df_questions)
assert kmo_general > 0.7

# %% [markdown]
# **Comentarios**

# %% [markdown]
# - Instancie un objeto con `FactorAnalyzer()` donde se estimen 10 dimensiones latentes y no se aplique rotación.
# - Genere un scree plot entre los eigenvalues del modelo y la cantidad de dimensiones estimables.

# %%
# Utiliza esta celda para generar los factores latentes y graficar sus valores propios
factores  = fact.FactorAnalyzer(n_factors=10, rotation=None).fit(df_questions)

# Extraer los valores propios

factor_screeplot = factores.get_eigenvalues()[0]

# Graficamos eigenvalues contra cantidad de estimables

plt.plot(
    range(1,len(factor_screeplot) + 1), # eje x
    factor_screeplot, # eje y
    'o-'
)

plt.xlabel('Número de factores')
plt.ylabel('Valores propios')
plt.xticks(range(1,len(factor_screeplot) + 1)) # para que grafique todos los valores del eje x
plt.axhline(1) # Criterio de corte
plt.title('Scree Plot')
plt.grid()

# %% [markdown]
# - Refactoriza el objeto con `FactorAnalyzer()` para incluir la cantidad de dimensiones válidas que informó el scree plot.
# - Extraiga las cargas $\lambda$ del modelo e identifique qué ítems están asociados a cada factor.

# %%
# Utiliza esta celda para generar los nuevos factores, extraer sus cargas, y mostrarlas en un dataframe con escala de colores
factorize_6 = fact.FactorAnalyzer(n_factors=6, rotation=None).fit(df_questions)
cargas = pd.DataFrame(
    factorize_6.loadings_,
    columns=[f'Factor {i}' for i in range (1,7)],
    index = df_questions.columns
    )

cargas[cargas > .4].fillna(0).round(3).style.format("{:.2f}").background_gradient(cmap='Purples').applymap(lambda x: 'color: transparent' if x == 0 else '')
# Out:
# <style type="text/css">
# #T_9c8d7_row0_col0, #T_9c8d7_row0_col1, #T_9c8d7_row0_col2, #T_9c8d7_row0_col3, #T_9c8d7_row0_col4, #T_9c8d7_row0_col5, #T_9c8d7_row1_col1, #T_9c8d7_row1_col2, #T_9c8d7_row1_col3, #T_9c8d7_row1_col4, #T_9c8d7_row1_col5, #T_9c8d7_row2_col1, #T_9c8d7_row2_col2, #T_9c8d7_row2_col3, #T_9c8d7_row2_col4, #T_9c8d7_row2_col5, #T_9c8d7_row3_col0, #T_9c8d7_row3_col1, #T_9c8d7_row3_col2, #T_9c8d7_row3_col3, #T_9c8d7_row3_col4, #T_9c8d7_row3_col5, #T_9c8d7_row4_col1, #T_9c8d7_row4_col2, #T_9c8d7_row4_col3, #T_9c8d7_row4_col4, #T_9c8d7_row4_col5, #T_9c8d7_row5_col0, #T_9c8d7_row5_col1, #T_9c8d7_row5_col3, #T_9c8d7_row5_col4, #T_9c8d7_row5_col5, #T_9c8d7_row6_col0, #T_9c8d7_row6_col1, #T_9c8d7_row6_col3, #T_9c8d7_row6_col4, #T_9c8d7_row6_col5, #T_9c8d7_row7_col0, #T_9c8d7_row7_col1, #T_9c8d7_row7_col2, #T_9c8d7_row7_col3, #T_9c8d7_row7_col4, #T_9c8d7_row7_col5, #T_9c8d7_row8_col0, #T_9c8d7_row8_col1, #T_9c8d7_row8_col2, #T_9c8d7_row8_col3, #T_9c8d7_row8_col4, #T_9c8d7_row8_col5, #T_9c8d7_row9_col0, #T_9c8d7_row9_col1, #T_9c8d7_row9_col2, #T_9c8d7_row9_col3, #T_9c8d7_row9_col4, #T_9c8d7_row9_col5, #T_9c8d7_row10_col0, #T_9c8d7_row10_col1, #T_9c8d7_row10_col2, #T_9c8d7_row10_col3, #T_9c8d7_row10_col4, #T_9c8d7_row10_col5, #T_9c8d7_row11_col0, #T_9c8d7_row11_col1, #T_9c8d7_row11_col2, #T_9c8d7_row11_col3, #T_9c8d7_row11_col4, #T_9c8d7_row11_col5, #T_9c8d7_row12_col1, #T_9c8d7_row12_col2, #T_9c8d7_row12_col3, #T_9c8d7_row12_col4, #T_9c8d7_row12_col5, #T_9c8d7_row13_col1, #T_9c8d7_row13_col2, #T_9c8d7_row13_col3, #T_9c8d7_row13_col4, #T_9c8d7_row13_col5, #T_9c8d7_row14_col1, #T_9c8d7_row14_col2, #T_9c8d7_row14_col3, #T_9c8d7_row14_col4, #T_9c8d7_row14_col5, #T_9c8d7_row15_col0, #T_9c8d7_row15_col2, #T_9c8d7_row15_col3, #T_9c8d7_row15_col4, #T_9c8d7_row15_col5, #T_9c8d7_row16_col0, #T_9c8d7_row16_col2, #T_9c8d7_row16_col3, #T_9c8d7_row16_col4, #T_9c8d7_row16_col5, #T_9c8d7_row17_col0, #T_9c8d7_row17_col2, #T_9c8d7_row17_col3, #T_9c8d7_row17_col4, #T_9c8d7_row17_col5, #T_9c8d7_row18_col0, #T_9c8d7_row18_col2, #T_9c8d7_row18_col3, #T_9c8d7_row18_col4, #T_9c8d7_row18_col5, #T_9c8d7_row19_col0, #T_9c8d7_row19_col2, #T_9c8d7_row19_col3, #T_9c8d7_row19_col4, #T_9c8d7_row19_col5, #T_9c8d7_row20_col0, #T_9c8d7_row20_col1, #T_9c8d7_row20_col2, #T_9c8d7_row20_col3, #T_9c8d7_row20_col4, #T_9c8d7_row20_col5, #T_9c8d7_row21_col0, #T_9c8d7_row21_col1, #T_9c8d7_row21_col2, #T_9c8d7_row21_col3, #T_9c8d7_row21_col4, #T_9c8d7_row21_col5, #T_9c8d7_row22_col0, #T_9c8d7_row22_col1, #T_9c8d7_row22_col2, #T_9c8d7_row22_col3, #T_9c8d7_row22_col4, #T_9c8d7_row22_col5, #T_9c8d7_row23_col0, #T_9c8d7_row23_col1, #T_9c8d7_row23_col2, #T_9c8d7_row23_col3, #T_9c8d7_row23_col4, #T_9c8d7_row23_col5, #T_9c8d7_row24_col0, #T_9c8d7_row24_col1, #T_9c8d7_row24_col2, #T_9c8d7_row24_col4, #T_9c8d7_row24_col5 {
#   background-color: #fcfbfd;
#   color: #000000;
#   color: transparent;
# }
# #T_9c8d7_row1_col0 {
#   background-color: #6a51a3;
#   color: #f1f1f1;
# }
# #T_9c8d7_row2_col0 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_9c8d7_row4_col0 {
#   background-color: #4a1587;
#   color: #f1f1f1;
# }
# #T_9c8d7_row5_col2 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_9c8d7_row6_col2, #T_9c8d7_row13_col0, #T_9c8d7_row15_col1, #T_9c8d7_row24_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_9c8d7_row12_col0 {
#   background-color: #50208c;
#   color: #f1f1f1;
# }
# #T_9c8d7_row14_col0 {
#   background-color: #582e92;
#   color: #f1f1f1;
# }
# #T_9c8d7_row16_col1 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_9c8d7_row17_col1 {
#   background-color: #481185;
#   color: #f1f1f1;
# }
# #T_9c8d7_row18_col1 {
#   background-color: #807cba;
#   color: #f1f1f1;
# }
# #T_9c8d7_row19_col1 {
#   background-color: #7d78b7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c8d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c8d7_level0_col0" class="col_heading level0 col0" >Factor 1</th>
#       <th id="T_9c8d7_level0_col1" class="col_heading level0 col1" >Factor 2</th>
#       <th id="T_9c8d7_level0_col2" class="col_heading level0 col2" >Factor 3</th>
#       <th id="T_9c8d7_level0_col3" class="col_heading level0 col3" >Factor 4</th>
#       <th id="T_9c8d7_level0_col4" class="col_heading level0 col4" >Factor 5</th>
#       <th id="T_9c8d7_level0_col5" class="col_heading level0 col5" >Factor 6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c8d7_level0_row0" class="row_heading level0 row0" >A1</th>
#       <td id="T_9c8d7_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_9c8d7_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_9c8d7_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_9c8d7_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_9c8d7_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_9c8d7_row0_col5" class="data row0 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row1" class="row_heading level0 row1" >A2</th>
#       <td id="T_9c8d7_row1_col0" class="data row1 col0" >0.46</td>
#       <td id="T_9c8d7_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_9c8d7_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_9c8d7_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_9c8d7_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_9c8d7_row1_col5" class="data row1 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row2" class="row_heading level0 row2" >A3</th>
#       <td id="T_9c8d7_row2_col0" class="data row2 col0" >0.52</td>
#       <td id="T_9c8d7_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_9c8d7_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_9c8d7_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_9c8d7_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_9c8d7_row2_col5" class="data row2 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row3" class="row_heading level0 row3" >A4</th>
#       <td id="T_9c8d7_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_9c8d7_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_9c8d7_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_9c8d7_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_9c8d7_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_9c8d7_row3_col5" class="data row3 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row4" class="row_heading level0 row4" >A5</th>
#       <td id="T_9c8d7_row4_col0" class="data row4 col0" >0.57</td>
#       <td id="T_9c8d7_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_9c8d7_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_9c8d7_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_9c8d7_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_9c8d7_row4_col5" class="data row4 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row5" class="row_heading level0 row5" >C1</th>
#       <td id="T_9c8d7_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_9c8d7_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_9c8d7_row5_col2" class="data row5 col2" >0.44</td>
#       <td id="T_9c8d7_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_9c8d7_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_9c8d7_row5_col5" class="data row5 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row6" class="row_heading level0 row6" >C2</th>
#       <td id="T_9c8d7_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_9c8d7_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_9c8d7_row6_col2" class="data row6 col2" >0.46</td>
#       <td id="T_9c8d7_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_9c8d7_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_9c8d7_row6_col5" class="data row6 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9c8d7_level0_row7" class="row_heading level0 row7" >C3</th>
#       <td id="T_9c8d7_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_9

# %% [markdown]
# **Comente sobre qué significa cada factor construído**

# %% [markdown]
# ## Desafío 5: Modelación de factores
# - Extraiga los puntajes del modelo factorial a su base de datos.
# - Grafique la densidad de cada uno con `kdplot`.

# %%
# Utiliza esta celda para extraer los puntajes y graficar su densidad
puntajes = pd.DataFrame(factorize_6.transform(df_questions), columns=[f'Factor_{i}' for i in range(1,7)])

for  c in puntajes.columns:
    sns.kdeplot(puntajes[c], label=c)

plt.legend()
plt.grid()

# %% [markdown]
# - Modele y comente brevemente sobre cuáles son los principales determinantes de cada factor en base al siguiente modelo estimable:
# $$
# y_i = \beta_0 + \beta_{gender} \cdot \text{gender}_i + \beta_{education} \cdot \text{education}_i + \beta_{age} \cdot \text{age}_i + \epsilon_i
# $$
#
# - $y$: Factor a modelar.

# %%
# Utiliza esta celda para entrenar los modelos solicitados. Se debe hacer un modelo paara cada factor.
df_modelo = pd.concat([
    df[["gender", "education", "age"]].reset_index(drop=True),
    puntajes
], axis=1)

df_modelo["gender"] = df_modelo["gender"].replace([1, 2], [1, 0])

df_modelo.head()
# Out:
#    gender  education  age  Factor_1  ...  Factor_3  Factor_4  Factor_5  Factor_6
# 0       0        3.0   21  1.104750  ...  0.777228  0.429006 -0.958366  0.076417
# 1       1        2.0   19 -2.177680  ...  0.511305 -0.211500 -0.730752 -0.523280
# 2       1        1.0   21 -0.015513  ... -0.403276  0.044932 -0.422234  0.065485
# 3       1        1.0   17 -0.273800  ...  0.925969  0.354409 -1.354209  0.213480
# 4       1        5.0   68  0.262650  ... -1.395966 -1.336868  0.644094 -0.395139
#
# [5 rows x 9 columns]

# %%
# Utiliza esta celda para mostrar los determinantes significativos del primer modelo
modelo_factor_1 = smf.ols("Factor_1 ~ gender + education + age", data=df_modelo).fit()

modelo_factor_1.summary2().tables[1]["P>|t|"] < 0.05
# Out:
# Intercept     True
# gender        True
# education    False
# age           True
# Name: P>|t|, dtype: bool

# %%
modelo_factor_1.summary2().tables[1]
# Out:
#               Coef.  Std.Err.         t         P>|t|    [0.025    0.975]
# Intercept -0.304146  0.075301 -4.039098  5.547045e-05 -0.451813 -0.156480
# gender    -0.181987  0.042285 -4.303863  1.750930e-05 -0.264909 -0.099066
# education  0.013771  0.018433  0.747100  4.550822e-01 -0.022376  0.049919
# age        0.010844  0.001924  5.637460  1.943944e-08  0.007072  0.014617

# %%
# Utiliza esta celda para mostrar los determinantes significativos del segundo modelo
modelo_factor_2 = smf.ols("Factor_2 ~ gender + education + age", data=df_modelo).fit()

modelo_factor_2.summary2().tables[1]["P>|t|"] < 0.05

# %%
# Utiliza esta celda para mostrar los determinantes significativos del tercer modelo

# %%
# Utiliza esta celda para mostrar los determinantes significativos del cuarto modelo

# %% [markdown]
# **Comentarios**
